# %%
from transformers import pipeline
import numpy as np
import pandas as pd
from datasets import Dataset, DatasetDict, load_dataset, Audio

# %%
df = pd.read_csv("musicnet_metadata_periods(Completed).csv", encoding="ISO-8859-1")

#all composers with more than 10 recordings in the dataset(from excel analaysis)
composer_list=['Beethoven', 'Bach', 'Schubert', 'Handel', 'Brahms', 'Schumann', 'Mozart', 'Dvorak', 'Vivaldi']

mydict={}
for composer in composer_list:
    #print(df.loc[df['composer'] == composer])
    mydf = df.loc[df['composer'] == composer]
    list_of_path=list(mydf['path'])
    mydict[composer]=list_of_path

# %%
from transformers import AutoFeatureExtractor

model_id = "ntu-spml/distilhubert"
feature_extractor = AutoFeatureExtractor.from_pretrained(
    model_id, do_normalize=True, return_attention_mask=True
)

# %%
sampling_rate = feature_extractor.sampling_rate
# Creating dataset with labels
data = {
    "audio": [],
    "label": []
}

for i in range(len(composer_list)):
    composer = composer_list[i]
    for audio_file in mydict[composer]:
        data["audio"].append(audio_file)  # Adding audio files
        data["label"].append(i)  # Assigning composer id as label

# Creating Dataset
dataset = Dataset.from_dict(data).cast_column("audio", Audio(sampling_rate=sampling_rate))
dataset = DatasetDict({"train": dataset})
dataset.save_to_disk("tempDataset") #since we are creating data from in-memory data, we save the dataset to disk to avoid filling up the RAM

# Check the first entry
print(dataset['train'])
# Out:
# Saving the dataset (0/54 shards):   0%|          | 0/443 [00:00<?, ? examples/s]
# Dataset({
#     features: ['audio', 'label'],
#     num_rows: 443
# })

# %%
label2id, id2label = dict(), dict()
for i, label in enumerate(composer_list):
    label2id[label] = str(i)
    id2label[str(i)] = label

print(id2label, '\n\n', label2id)
print(id2label['0'])
print(label2id['Beethoven'])
# Out:
# {'0': 'Beethoven', '1': 'Bach', '2': 'Schubert', '3': 'Handel', '4': 'Brahms', '5': 'Schumann', '6': 'Mozart', '7': 'Dvorak', '8': 'Vivaldi'}
#
#  {'Beethoven': '0', 'Bach': '1', 'Schubert': '2', 'Handel': '3', 'Brahms': '4', 'Schumann': '5', 'Mozart': '6', 'Dvorak': '7', 'Vivaldi': '8'}
# Beethoven
# 0

# %%
import math
max_duration = 3 

def subdivide_function(entry):
    audio_array = entry["audio"][0]['array']
    audio_label = entry['label'][0]
    print(entry)
    #print(audio_label)
    sampling_rate = feature_extractor.sampling_rate
    segment_length = int(sampling_rate * max_duration)
    
    #print(len(audio_array))
    num_segments = math.ceil(len(audio_array) / segment_length)
    chunks = []
    labels = []
    for i in range(num_segments):
        start_idx = i * segment_length
        end_idx = start_idx + segment_length
        if end_idx >= len(audio_array):
            segment = audio_array[start_idx:] #meaning last segment already
        else:
            segment = audio_array[start_idx:end_idx] #meaning still in the middle
        #print(segment)
        labels.append(audio_label)
        chunks.append(segment)

    return {"labels": labels,
            "chunks": chunks}
    
dataset = DatasetDict.load_from_disk("tempDataset")
chunked_dataset = dataset.map(subdivide_function, batch_size = 1, batched=True, remove_columns=['audio', 'label'])
# Out:
# Loading dataset from disk:   0%|          | 0/54 [00:00<?, ?it/s]
# Map:   0%|          | 0/443 [00:00<?, ? examples/s]
# {'audio': [{'path': 'Romantic.008.wav', 'array': array([-4.46251619e-10,  6.09580997e-10, -5.98676220e-10, ...,
#         9.07644571e-05,  1.85598547e-04,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.009.wav', 'array': array([ 7.78915266e-11,  2.60398439e-11,  4.99640433e-12, ...,
#        -2.01829571e-05, -2.16683147e-05,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.010.wav', 'array': array([ 6.77716494e-11,  5.84781390e-11,  1.03103415e-10, ...,
#        -1.60852243e-04, -1.64244295e-04, -2.00809722e-04]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.011.wav', 'array': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#        4.50815736e-14, 5.25562734e-14, 0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.052.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.053.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.054.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.055.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.056.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.057.wav', 'array': array([-2.02445366e-10, -3.85677018e-10, -1.13869275e-10, ...,
#         2.05374468e-04,  1.63498335e-05,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.058.wav', 'array': array([-2.18093224e-10, -2.91648719e-11,  2.08357206e-10, ...,
#         2.45331274e-03,  2.72672949e-03,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.059.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.060.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.061.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.062.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.063.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.064.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.065.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.066.wav', 'array': array([-1.06621947e-10, -1.88242824e-10, -1.34601358e-10, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.067.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.073.wav', 'array': array([ 3.07374699e-12, -1.03609536e-12, -2.03640598e-12, ...,
#        -1.18068988e-06,  9.26997382e-06,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.074.wav', 'array': array([-9.79990394e-13, -2.21215390e-11,  7.47416538e-12, ...,
#         4.60167848e-06, -9.68639824e-07,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.075.wav', 'array': array([-2.54286566e-12,  5.27808743e-12, -4.06333821e-12, ...,
#         3.25987486e-07, -2.76445633e-07,  2.28801596e-07]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.079.wav', 'array': array([-1.94642638e-07,  1.84809494e-07, -1.65292150e-07, ...,
#        -7.92702394e-07,  6.74026865e-07,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.080.wav', 'array': array([-1.94663812e-07,  1.85048734e-07, -1.65238305e-07, ...,
#         3.62313699e-06, -1.04098881e-05, -1.06680518e-05]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.081.wav', 'array': array([-7.99471127e-06, -5.49642164e-06,  2.34375852e-06, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.082.wav', 'array': array([-1.94641984e-07,  1.84806851e-07, -1.65295816e-07, ...,
#        -1.01172907e-06,  6.26152939e-07,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.083.wav', 'array': array([ 2.11810170e-13,  5.30485703e-13,  5.29386105e-13, ...,
#         1.07248798e-06, -8.68433972e-07,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.084.wav', 'array': array([-2.75021783e-10, -1.08095255e-10,  9.42166345e-11, ...,
#        -9.22156573e-08,  9.79728441e-08,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.085.wav', 'array': array([-4.20259869e-11,  2.06506444e-11,  1.29930320e-11, ...,
#         2.43856562e-08, -1.71104261e-07,  2.59038018e-07]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.086.wav', 'array': array([-8.25232473e-06, -5.28198552e-06,  2.19176309e-06, ...,
#        -2.85666488e-06,  1.80163306e-06, -1.32244622e-06]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.087.wav', 'array': array([-1.94721252e-07,  1.84770570e-07, -1.65325019e-07, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.088.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         2.92747927e-07, -2.54612758e-07,  2.15991292e-07]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.089.wav', 'array': array([-1.94693641e-07,  1.84873869e-07, -1.65377088e-07, ...,
#        -1.36975657e-07,  1.90240499e-07,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.090.wav', 'array': array([-8.39229142e-06, -5.08478388e-06,  1.94288600e-06, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.091.wav', 'array': array([-1.94643462e-07,  1.84807249e-07, -1.65296910e-07, ...,
#        -1.05716163e-06,  2.07804669e-06, -8.73672252e-06]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.092.wav', 'array': array([-1.94568429e-07,  1.84839180e-07, -1.65275964e-07, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Romantic.093.wav', 'array': array([-2.71388984e-07,  3.30680223e-07, -3.76539106e-07, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.004.wav', 'array': array([-1.38500905e-10, -6.21901003e-11, -2.43579861e-11, ...,
#        -4.19589778e-05,  8.57053874e-06, -3.69855879e-05]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical
-07, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.140.wav', 'array': array([ 5.92350830e-07, -1.08741096e-05, -9.99426220e-07, ...,
#        -2.79698899e-13, -2.14622225e-14,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.141.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         2.29398589e-04, -3.83489387e-05,  1.27029431e-04]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.142.wav', 'array': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#        1.49783846e-05, 7.85443899e-06, 0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.143.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -2.56982342e-15, -2.49738584e-14, -2.06666851e-13]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.144.wav', 'array': array([-1.21922380e-14, -4.07049814e-15,  8.65642803e-14, ...,
#         1.67363467e-11,  8.07923173e-13, -4.97427551e-11]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.145.wav', 'array': array([5.77137426e-12, 2.80256617e-11, 2.62938846e-12, ...,
#        2.13176361e-04, 1.50471940e-04, 0.00000000e+00]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.146.wav', 'array': array([-1.59214031e-11, -7.72039030e-12, -2.14950262e-11, ...,
#         4.81611554e-04,  4.65240388e-04,  5.80569380e-04]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.147.wav', 'array': array([-3.09974546e-11, -8.08272112e-12,  3.53764448e-11, ...,
#         4.63883407e-06, -2.04185540e-07, -9.79216929e-06]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.148.wav', 'array': array([-1.94698728e-07,  1.84888080e-07, -1.65396585e-07, ...,
#        -9.72164980e-06,  4.65038556e-06, -1.28634347e-05]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.149.wav', 'array': array([-1.94643874e-07,  1.84822909e-07, -1.65329823e-07, ...,
#        -8.00555654e-07,  6.61044737e-07, -5.51846938e-07]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.150.wav', 'array': array([ 0.       ,  0.       ,  0.       , ..., -0.0012179, -0.0013013,
#         0.       ]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Classical.151.wav', 'array': array([ 1.27524059e-11, -6.70688331e-13,  4.00875652e-11, ...,
#        -1.77598954e-03, -2.09932472e-03, -1.86090963e-03]), 'sampling_rate': 16000}], 'label': [0]}
# {'audio': [{'path': 'Baroque.001.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         4.36930986e-06,  8.86010457e-06, -7.46243472e-07]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.002.wav', 'array': array([-1.95345152e-07,  1.84434597e-07, -1.66206377e-07, ...,
#        -4.30188472e-08,  8.60823235e-09,  1.92506704e-08]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.003.wav', 'array': array([-8.03049988e-06, -5.49516199e-06,  2.38262328e-06, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.004.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         2.27061696e-06, -1.30038802e-06,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.005.wav', 'array': array([-1.94414042e-07,  1.84937278e-07, -1.65005190e-07, ...,
#        -2.79735861e-08,  3.18788658e-08,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.006.wav', 'array': array([-1.94802951e-07,  1.85058866e-07, -1.65610146e-07, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.007.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -9.71191184e-06, -7.92346873e-06,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.008.wav', 'array': array([-6.75418050e-07,  7.43718431e-07, -7.77920889e-07, ...,
#         3.34241098e-13, -8.05237496e-14,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.009.wav', 'array': array([-8.66168193e-06, -3.73121020e-06,  1.36602748e-05, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.010.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         8.33143531e-06,  5.20727190e-06, -2.26204293e-06]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.011.wav', 'array': array([-1.94810298e-07,  1.84691302e-07, -1.65495862e-07, ...,
#         1.05282998e-05,  7.68014729e-07,  7.39146299e-06]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.012.wav', 'array': array([-8.36017080e-06, -5.07464574e-06,  1.89010598e-06, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.013.wav', 'array': array([-6.28129007e-11, -4.28834607e-11, -1.66587341e-10, ...,
#         2.31943862e-03,  1.99718936e-03,  1.78030145e-03]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.014.wav', 'array': array([4.33358405e-10, 3.64234864e-10, 1.01689690e-09, ...,
#        3.73415975e-03, 3.66051472e-03, 3.94406449e-03]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.015.wav', 'array': array([ 1.55981381e-10,  5.12046516e-11,  2.96104009e-11, ...,
#        -3.61120049e-03, -4.00680443e-03,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque
...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.048.wav', 'array': array([ 1.11797680e-11,  2.71296596e-11,  2.00713716e-11, ...,
#        -1.68486423e-11, -8.25194340e-12,  8.30065183e-11]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.049.wav', 'array': array([-1.56329225e-12,  3.73914302e-11,  2.16168923e-11, ...,
#         4.13360578e-12,  6.69012545e-12, -3.51941956e-12]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.050.wav', 'array': array([-3.11482264e-11, -5.34862363e-11, -4.41917197e-11, ...,
#        -2.97280213e-13, -2.05179434e-13,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.051.wav', 'array': array([ 3.30498094e-11,  1.36241391e-11,  6.05064679e-11, ...,
#        -8.82931506e-09,  9.15218124e-09,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.052.wav', 'array': array([ 6.98850092e-12,  7.00532271e-11, -6.02182280e-12, ...,
#         2.02342609e-09, -1.39820400e-09,  8.60164162e-10]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.053.wav', 'array': array([2.65899747e-10, 3.30461297e-10, 5.19375876e-10, ...,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.054.wav', 'array': array([ 1.66158563e-11,  3.14135762e-12,  1.07682743e-13, ...,
#         3.34981012e-13, -6.30731022e-14,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.055.wav', 'array': array([-1.52739783e-11, -1.82693062e-11, -5.79012706e-12, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.056.wav', 'array': array([ 1.87998506e-11,  6.62139232e-11,  4.26274537e-11, ...,
#         1.00727618e-07, -1.24837811e-07,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.057.wav', 'array': array([ 1.09050772e-11,  2.60091289e-11, -1.01110561e-11, ...,
#         5.92639273e-14,  1.19453140e-13,  5.60404316e-14]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.058.wav', 'array': array([-1.08434421e-10,  1.44234451e-12, -1.96119981e-10, ...,
#         1.14367413e-12,  1.13079598e-11,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.059.wav', 'array': array([ 1.02141897e-11, -2.63877583e-11, -7.44890694e-13, ...,
#         8.31474299e-12,  6.41177250e-11,  2.99104318e-11]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.060.wav', 'array': array([ 1.37495057e-10, -3.98655484e-11,  5.54911256e-11, ...,
#        -7.14420123e-09,  1.38793492e-08,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.061.wav', 'array': array([ 2.39398952e-11, -1.97223037e-11, -3.44858274e-11, ...,
#        -1.75955119e-11,  8.84834914e-12, -3.40399497e-12]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.062.wav', 'array': array([ 3.40316074e-11,  1.26459138e-11,  7.52215651e-12, ...,
#         7.13492647e-14, -1.63860319e-14,  2.48833174e-14]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.063.wav', 'array': array([-4.01916070e-11,  3.44504043e-11, -6.84897833e-11, ...,
#         1.04755518e-11,  1.98192209e-11,  4.06242782e-11]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.064.wav', 'array': array([ 1.20874430e-11,  7.39918370e-12,  5.42362925e-11, ...,
#        -7.92687658e-08,  6.08071886e-08,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.065.wav', 'array': array([9.43836329e-12, 2.70188364e-12, 7.76860694e-12, ...,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.066.wav', 'array': array([-1.76914341e-08,  2.31908288e-08, -2.72650507e-08, ...,
#         5.88003616e-07, -4.18643253e-07,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.067.wav', 'array': array([ 2.34321286e-12, -4.85242194e-11, -9.34572038e-12, ...,
#        -1.29688452e-14,  1.81239694e-13,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.068.wav', 'array': array([ 2.03644284e-08, -2.20476117e-08,  2.26237429e-08, ...,
#        -8.47812487e-09, -2.15837970e-09,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.069.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -3.73616876e-06, -8.17093496e-06, -1.49843545e-05]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.070.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.071.wav', 'array': array([-0.00048828, -0.00054932, -0.00048828, ..., -0.00033569,
#        -0.00030518, -0.00048828]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.072.wav', 'array': array([ 3.05175781e-05, -1.22070312e-04,  1.22070312e-04, ...,
#         3.05175781e-03,  2.77709961e-03,  1.15966797e-03]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.073.wav', 'array': array([-0.0098877 , -0.00082397,  0.01428223, ..., -0.00021362,
#        -0.00027466,  0.        ]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.074.wav', 'array': array([ 0.00030518,  0.0005188 ,  0.00033569, ..., -0.0043335 ,
#        -0.08209229, -0.10122681]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.075.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         5.29792214e-06, -1.62687120e-05,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.076.wav', 'array': array([-0.00042725, -0.00097656, -0.00091553, ..., -0.0005188 ,
#        -0.00018311, -0.00021362]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.077.wav', 'array': array([-0.00012207,  0.00015259,  0.00030518, ...,  0.00012207,
#         0.00021362,  0.        ]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.078.wav', 'array': array([-0.00054932, -0.00061035, -0.00036621, ..., -0.00045776,
#        -0.00048828, -0.00057983]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.079.wav', 'array': array([8.85009766e-04, 6.40869141e-04, 4.88281250e-04, ...,
#        6.10351562e-05, 3.66210938e-04, 1.83105469e-04]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.080.wav', 'array': array([ 0.0017395 ,  0.00164795,  0.00164795, ..., -0.00213623,
#        -0.0017395 , -0.0010376 ]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.081.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.082.wav', 'array': array([-1.42108547e-13,  1.70530257e-13,  4.26325641e-13, ...,
#        -2.27373675e-12,  5.00222086e-12, -1.81898940e-12]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.083.wav', 'array': array([-2.41584530e-13, -8.52651283e-14,  0.00000000e+00, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.084.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         4.43378667e-11, -3.41060513e-11,  2.09183781e-11]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.085.wav', 'array': array([ 1.42108547e-13,  1.13686838e-13, -1.13686838e-13, ...,
#        -8.18545232e-12,  2.18278728e-11, -9.09494702e-12]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.086.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.087.wav', 'array': array([-1.17239551e-13,  0.00000000e+00, -2.48689958e-13, ...,
#        -9.09494702e-13, -9.09494702e-13, -9.09494702e-13]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.088.wav', 'array': array([-8.31872148e-06, -6.96603911e-06, -2.08788151e-05, ...,
#         1.93418353e-04,  1.86446327e-04,  1.63169709e-04]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.089.wav', 'array': array([ 8.74367834e-05,  1.71139051e-04,  1.33290610e-04, ...,
#        -1.05639883e-05, -1.66239388e-05, -1.17404343e-05]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.090.wav', 'array': array([-1.73840763e-05, -2.88934934e-05, -2.94144029e-05, ...,
#        -6.38168829e-04, -5.98288607e-04, -6.68628607e-04]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.091.wav', 'array': array([-3.79159872e-04, -6.91822963e-04, -5.71600918e-04, ...,
#        -7.00520377e-06, -7.37333266e-06,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.092.wav', 'array': array([-1.37870875e-05, -2.56767089e-05, -2.24149408e-05, ...,
#        -5.10349753e-04, -5.62639907e-04,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.093.wav', 'array': array([-0.00030655, -0.0005578 , -0.00047378, ..., -0.00537949,
#        -0.00487353, -0.00469445]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.094.wav', 'array': array([-1.00819269e-13,  6.53094278e-13, -1.26624850e-12, ...,
#         1.66507997e-12,  2.26992497e-13,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.095.wav', 'array': array([ 1.15259218e-05,  1.00051675e-05, -2.02821611e-05, ...,
#         6.05872629e-07,  9.67703636e-06,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.096.wav', 'array': array([-7.54485780e-04, -1.37552223e-03, -1.35275489e-03, ...,
#        -4.74700482e-06,  1.09550206e-06,  3.79245807e-06]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.097.wav', 'array': array([-3.62793100e-04, -6.61933271e-04, -9.25834465e-04, ...,
#         5.05269008e-06, -3.46854176e-06,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.098.wav', 'array': array([-6.51022401e-06,  1.39902477e-04,  1.73376146e-04, ...,
#        -6.98857912e-06, -2.05334800e-05,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.099.wav', 'array': array([-6.75438423e-05, -1.47947110e-04, -2.32393126e-04, ...,
#         1.55223206e-05, -1.55729103e-05,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [1]}
# {'audio': [{'path': 'Baroque.100.wav', 'array': array([0.00014539, 0.00056814, 0.00073452, ..., 0.00335352, 0.00400717,
#        0.        ]), 'sampling_rate': 16000}], 'label': [1]}
# ...
# {'audio': [{'path': 'Romantic.098.wav', 'array': array([ 2.95941500e-11,  3.24243098e-11,  4.26465460e-11, ...,
#         8.74235795e-09, -1.12612719e-08,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [4]}
# {'audio': [{'path': 'Romantic.099.wav', 'array': array([-1.94781620e-07,  1.84684424e-07, -1.65429455e-07, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [4]}
# {'audio': [{'path': 'Romantic.100.wav', 'array': array([-1.94621048e-08,  1.69734129e-08, -1.33064813e-08, ...,
#        -1.46444090e-05, -1.62605429e-05,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.101.wav', 'array': array([-0.0002313 , -0.00043875, -0.0004718 , ..., -0.00018274,
#        -0.00013324,  0.        ]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.102.wav', 'array': array([-0.00024216, -0.00053576, -0.00066405, ...,  0.0003502 ,
#         0.00058076,  0.        ]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.103.wav', 'array': array([ 1.69812018e-04,  1.35677226e-04, -5.57673775e-05, ...,
#        -3.26993613e-05,  1.74581553e-04,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.104.wav', 'array': array([ 3.95056268e-05,  1.29033477e-04, -4.63508113e-05, ...,
#        -7.18181895e-04, -9.40147089e-04,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.105.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.106.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.107.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.108.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -3.05427602e-05, -3.03164106e-05, -3.09297320e-05]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.109.wav', 'array': array([-6.16265936e-08,  5.30347535e-08, -4.18739390e-08, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.110.wav', 'array': array([ 2.37287061e-08, -3.82226872e-08,  5.00797412e-08, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.134.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -1.10980072e-05, -2.11480656e-05, -3.97486292e-06]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.135.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -2.03914969e-05, -2.19724461e-05, -1.38268688e-05]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.136.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.137.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -1.56045826e-05, -1.37367924e-05, -5.50878804e-06]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.138.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -1.81898940e-12, -1.36424205e-12, -1.36424205e-12]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.139.wav', 'array': array([ 4.97379915e-14, -8.88178420e-14, -2.27373675e-13, ...,
#        -4.54747351e-13,  4.54747351e-13,  4.54747351e-13]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.140.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -2.01784678e-05, -3.54361532e-06, -1.73240696e-05]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.141.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -1.54827721e-05, -1.62978558e-05, -3.49475044e-06]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.142.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -6.20524452e-06, -1.35043847e-05, -1.35791406e-05]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.143.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -3.74802767e-09,  2.88127922e-09, -2.11480256e-09]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.144.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -2.70169930e-05, -2.43154318e-06, -2.00394006e-05]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.145.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Romantic.146.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -3.34785000e-09,  3.35785444e-09, -3.25439942e-09]), 'sampling_rate': 16000}], 'label': [5]}
# {'audio': [{'path': 'Classical.001.wav', 'array': array([-1.46746122e-11,  1.66183560e-11, -1.68550229e-10, ...,
#        -1.73602533e-03, -2.02083192e-03,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.002.wav', 'array': array([-3.00675235e-10, -2.62377065e-10, -2.65548528e-10, ...,
#        -7.53674423e-04, -1.00458041e-03, -8.08209530e-04]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.003.wav', 'array': array([ 1.37211867e-10,  6.74070244e-11,  1.69753767e-10, ...,
#        -6.76830459e-05, -2.69247364e-04,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.085.wav', 'array': array([-1.94692234e-07,  1.84861989e-07, -1.65375326e-07, ...,
#        -2.06273057e-07,  3.64821346e-07, -4.08848678e-07]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.086.wav', 'array': array([-1.94627148e-07,  1.84798026e-07, -1.65269711e-07, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.087.wav', 'array': array([-1.94630815e-07,  1.84846584e-07, -1.65309274e-07, ...,
#        -7.91933599e-06,  6.34713024e-06, -5.34350602e-06]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.088.wav', 'array': array([-1.94692319e-07,  1.84859061e-07, -1.65392223e-07, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.089.wav', 'array': array([-8.12088456e-06, -5.38111453e-06,  2.25094982e-06, ...,
#        -4.70961261e-08,  2.57575454e-08, -6.85761492e-09]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.090.wav', 'array': array([-8.04360479e-06, -5.43706756e-06,  2.28416320e-06, ...,
#        -1.05883828e-06,  9.23721245e-07,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.094.wav', 'array': array([-1.33735648e-10, -1.74831052e-11, -1.64545766e-10, ...,
#         9.38023504e-07,  9.98285304e-06, -1.79427900e-06]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.095.wav', 'array': array([ 9.39611305e-11, -4.85765178e-11, -2.78035303e-11, ...,
#        -4.33506466e-06, -1.33565879e-06,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.096.wav', 'array': array([-1.46770707e-10, -1.80969142e-10, -2.30162958e-10, ...,
#         3.07436312e-06,  1.71579850e-05,  2.55735722e-06]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.108.wav', 'array': array([-1.94705095e-07,  1.84906497e-07, -1.65490235e-07, ...,
#         2.69523025e-06, -8.04981391e-06, -6.06697358e-06]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.109.wav', 'array': array([ 2.42279530e-08, -3.37450565e-08,  4.26016769e-08, ...,
#        -8.97634891e-07,  7.08433049e-07, -5.81078780e-07]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.110.wav', 'array': array([-2.84898109e-14,  1.16848276e-13, -1.20732661e-13, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.111.wav', 'array': array([-9.60658549e-12,  2.08097949e-11, -3.37547004e-11, ...,
#         1.13872843e-12, -3.87541214e-12,  2.15506562e-12]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.112.wav', 'array': array([-8.07026936e-06, -5.39673465e-06,  2.23219922e-06, ...,
#         4.77877393e-07, -5.73310444e-07,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.113.wav', 'array': array([-3.74584431e-14,  1.33107772e-13,  5.62138294e-14, ...,
#        -1.77342743e-12, -3.80614594e-14,  1.66943174e-12]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.114.wav', 'array': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#        5.40831052e-13, 1.67080651e-12, 0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.115.wav', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.116.wav', 'array': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#        1.58150257e-08, 9.69720393e-09, 0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.117.wav', 'array': array([-1.88426640e-07,  1.51914293e-07, -1.07922432e-07, ...,
#        -1.12850184e-05, -1.79119052e-05,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.118.wav', 'array': array([-1.94663428e-07,  1.84846996e-07, -1.65240522e-07, ...,
#        -3.58271990e-08,  3.26695258e-08,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Classical.121.wav', 'array': array([-4.32477378e-08,  5.19833065e-09,  4.82880750e-07, ...,
#        -1.48412494e-06,  2.37291670e-06, -6.88048931e-06]), 'sampling_rate': 16000}], 'label': [6]}
# {'audio': [{'path': 'Romantic.076.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         1.14039366e-12, -1.51214978e-13, -3.93713858e-16]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Romantic.077.wav', 'array': array([ 3.08307863e-14,  5.03424071e-14, -8.24313355e-14, ...,
#        -5.22517274e-09,  4.79358109e-09, -4.30586233e-09]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Romantic.078.wav', 'array': array([-5.02364636e-14, -1.19011870e-13, -3.52455763e-14, ...,
#        -1.78269313e-12, -1.47358362e-12, -3.34469019e-12]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Romantic.123.wav', 'array': array([ 2.05477534e-07, -2.39471092e-07,  2.60368211e-07, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Romantic.128.wav', 'array': array([-1.57160684e-05, -8.32043588e-06, -2.55401246e-05, ...,
#         4.74979356e-03,  4.12285514e-03,  4.19307873e-03]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Romantic.129.wav', 'array': array([-4.16534021e-06, -2.21966766e-05, -1.52247958e-05, ...,
#         3.89637752e-03,  3.92366853e-03,  4.23811190e-03]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Romantic.130.wav', 'array': array([-1.76997855e-05, -1.93822198e-05, -1.21146441e-05, ...,
#         3.55664082e-03,  3.20294360e-03,  3.41463438e-03]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Romantic.131.wav', 'array': array([-1.02418539e-07,  7.75778446e-08, -4.93820522e-08, ...,
#        -3.00670381e-05, -3.10880023e-05, -2.89631098e-05]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Romantic.132.wav', 'array': array([ 1.43158907e-08, -1.65420584e-08,  1.71097305e-08, ...,
#        -1.49545685e-05, -1.56793394e-05, -1.40911980e-05]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Romantic.133.wav', 'array': array([ 1.58353785e-07, -1.23431974e-07,  8.17222769e-08, ...,
#        -1.45061249e-05, -1.66935115e-05,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Classical.101.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         8.89263163e-07, -9.17383261e-07,  9.16388615e-07]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Classical.102.wav', 'array': array([-5.40834687e-15, -8.86939312e-14, -7.10695744e-14, ...,
#        -1.60980107e-07,  1.73495863e-07, -1.80481436e-07]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Classical.103.wav', 'array': array([-1.13796166e-13, -3.38211006e-14,  1.27177491e-14, ...,
#        -7.14518641e-14, -2.23523869e-12, -1.11041081e-12]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Classical.104.wav', 'array': array([ 1.86648833e-13, -4.48309358e-13, -3.30806617e-13, ...,
#        -1.63765378e-07,  7.12276062e-07, -1.05048621e-05]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Classical.105.wav', 'array': array([-1.94691552e-07,  1.84883675e-07, -1.65424240e-07, ...,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 16000}], 'label': [7]}
# {'audio': [{'path': 'Baroque.139.wav', 'array': array([-5.35765139e-08,  1.04183073e-07, -1.60584023e-07, ...,
#        -2.11507140e-05, -2.03822856e-06, -9.97615280e-06]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.140.wav', 'array': array([-1.79534254e-07,  2.00714567e-07, -2.19632057e-07, ...,
#        -1.94490331e-05, -2.87056846e-05, -2.01146595e-05]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.141.wav', 'array': array([-1.38563337e-07,  1.77213224e-07, -2.18991772e-07, ...,
#        -5.21703214e-09,  3.03940162e-09, -1.14543752e-09]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.142.wav', 'array': array([-2.91038305e-10, -2.61934474e-10,  2.91038305e-11, ...,
#        -1.79600902e-05, -1.73964072e-05, -1.53386500e-05]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.143.wav', 'array': array([-1.71421561e-07,  1.71086867e-07, -1.67114194e-07, ...,
#         1.22026904e-08, -1.10530891e-08,  9.75160219e-09]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.144.wav', 'array': array([-1.01863407e-10, -5.82076609e-11,  2.18278728e-11, ...,
#        -1.59342890e-05, -2.87687435e-05, -3.29368631e-05]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.145.wav', 'array': array([-5.75149897e-07,  6.62505045e-07, -7.51446350e-07, ...,
#        -1.21683570e-08,  1.00651505e-08, -8.01333044e-09]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.146.wav', 'array': array([ 2.74863851e-07, -2.73459591e-07,  2.65114068e-07, ...,
#        -1.10288165e-05, -3.16353762e-05, -3.16618061e-05]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.147.wav', 'array': array([-9.60280886e-08,  9.91858542e-08, -1.01063051e-07, ...,
#        -1.84733100e-08,  1.63384044e-08, -1.41657530e-08]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.148.wav', 'array': array([ 3.78349796e-08,  1.45519152e-09, -6.53089955e-08, ...,
#         1.98042102e-07, -5.78964045e-06, -6.57484907e-06]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.149.wav', 'array': array([-7.10933818e-08,  5.86733222e-08, -4.19749995e-08, ...,
#        -1.38805353e-05, -2.06696459e-05, -2.32024395e-05]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.150.wav', 'array': array([ 1.45519152e-11,  2.91038305e-11,  2.91038305e-11, ...,
#        -1.39448093e-06, -2.05439865e-05, -4.08948399e-05]), 'sampling_rate': 16000}], 'label': [8]}
# {'audio': [{'path': 'Baroque.151.wav', 'array': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#        1.38100187e-12, 1.67501809e-12, 0.00000000e+00]), 'sampling_rate': 16000}], 'label': [8]}

# %%
chunked_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'chunks'],
#         num_rows: 50768
#     })
# })

# %%
chunked_dataset = chunked_dataset["train"].train_test_split(seed=42, shuffle=True, test_size=0.1)

# %%
chunked_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'chunks'],
#         num_rows: 45691
#     })
#     test: Dataset({
#         features: ['labels', 'chunks'],
#         num_rows: 5077
#     })
# })

# %%
def preprocess_function(examples):
    audio_arrays = examples['chunks']
    inputs = feature_extractor(
        audio_arrays,
        sampling_rate=feature_extractor.sampling_rate,
        max_length=int(feature_extractor.sampling_rate * max_duration),
        truncation=True,
        return_attention_mask=True,
    )
    return inputs

dataset_encoded = chunked_dataset.map(
    preprocess_function,
    remove_columns=["chunks"],
    batched=True,
    batch_size=100,
    num_proc=1,
)
dataset_encoded = dataset_encoded.rename_column("labels", "label")
dataset_encoded
# Out:
# Map:   0%|          | 0/45691 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5077 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_values', 'attention_mask'],
#         num_rows: 45691
#     })
#     test: Dataset({
#         features: ['label', 'input_values', 'attention_mask'],
#         num_rows: 5077
#     })
# })

# %%
from transformers import AutoModelForAudioClassification

num_labels = len(id2label)

model = AutoModelForAudioClassification.from_pretrained(
    model_id,
    num_labels=num_labels,
    label2id=label2id,
    id2label=id2label,
)
# Out:
# Some weights of HubertForSequenceClassification were not initialized from the model checkpoint at ntu-spml/distilhubert and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments

model_name = model_id.split("/")[-1]
batch_size = 4
gradient_accumulation_steps = 1
num_train_epochs = 10

training_args = TrainingArguments(
    f"{model_name}-finetuned-dataset",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=num_train_epochs,
    warmup_ratio=0.1,
    logging_steps=5,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    fp16=True,
    push_to_hub=False,
)
# Out:
# C:\Users\young\anaconda3\envs\ClassicalMusicClassify\Lib\site-packages\transformers\training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
import evaluate
import numpy as np

metric = evaluate.load("accuracy")


def compute_metrics(eval_pred):
    """Computes accuracy on a batch of predictions"""
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

# %%
from transformers import Trainer

trainer = Trainer(
    model,
    training_args,
    train_dataset=dataset_encoded["train"].with_format("torch"),
    eval_dataset=dataset_encoded["test"].with_format("torch"),
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
)

trainer.train()
trainer.save_model("ComposerClassifyModel")
# Out:
# C:\Users\young\AppData\Local\Temp\ipykernel_51176\1161299834.py:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='114230' max='114230' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [114230/114230 3:25:23, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.972800</td>
#       <td>0.882707</td>
#       <td>0.712429</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.245200</td>
#       <td>0.901450</td>
#       <td>0.775458</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.407400</td>
#       <td>0.683199</td>
#       <td>0.836912</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.523800</td>
#       <td>0.628899</td>
#       <td>0.892259</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.001300</td>
#       <td>0.626021</td>
#       <td>0.896396</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.476800</td>
#       <td>0.571036</td>
#       <td>0.918653</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000600</td>
#       <td>0.595652</td>
#       <td>0.913926</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.641279</td>
#       <td>0.922395</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.604442</td>
#       <td>0.931062</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000700</td>
#       <td>0.564171</td>
#       <td>0.936971</td>
#     </tr>
#   </tbody>
# </table><p>
